# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [10, 20]       # 10s + 20
den = [1, 15, 50, 0]    # s^3 + 15s^2 + 50s + 0
G = ctrl.tf(num, den)
print(G)

# %% [markdown]
# poles = ctrl.poles(G)
# print("Poles:", poles)

# %%
zero = ctrl.zeros(G)
print("Zero:", zero)

# %%
import matplotlib.pyplot as plt

ctrl.pzmap(G, grid=True)
plt.show()
